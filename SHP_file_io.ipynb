# %% [markdown]
# File IO

# %%
'''first step is to upload the data on the LHS

then open the data in code:'''



##with open("/content/test.txt") as f: #these are equivalent, whichever way you prefer

#print(f) #what is going to print here?

#print(f.read()) #what is going to print here?

#print(f.readline()) #what is going to print here?

#print(f.readlines()) #what is going to print here?

#print(f.readline(5)) #what is going to print here?

# %%
'''how would we loop though each line? Say we wanted to count them?'''


f = open("/content/test.txt")

# counter = 0
# for line in f:
#   #print(line[:-1])      #What is this going to do? How do we fix this?
#   counter+=1
#   if counter == 10:
#     print(line)

# print(counter)

'''how would we loop though each word? Saw we wanted to count those?'''


# counter = 0
# for line in f:
#   for x in line:
#     print(x)      #will this work?
#     counter+=1

# print(counter)


# counter = 0
# for word in f.read().split():
#   print(word)

# print(counter)

"See if a word exists in a file"

search = "wish"
print(search in f.read())




#f.close()
# Out:
# False

# %%
'''writting to files: NOTE COLLAB DOES NOT LET YOU PUT EMPTY FILES
Next upload file as usual'''

#tip: make sure you save every time with files: they don't save automatically


w = open("/content/write.txt", 'a')

w.write("Python!") #what will the file look like after this


'''Let's print every other line of the song into this file'''
w.close() #CLOSED

# %%
'''Writing again'''

w = open("/content/write.txt", 'w')

w.write("Hello") #what will the file look like after this


'''Let's print every other line of the song into this file'''
w.close()

# %%
#lab solution:

# Fanier way with unseen techniques:

# with open('/content/test.txt') as fh1, open('/content/write.txt') as fh2:
#     for line1, line2 in zip(fh1, fh2):
#         # line1 from abc.txt, line2 from test.txtg
#         print(line1+line2)


# Using class taught techniques:

# fh1 = open('/content/test.txt')
# fh2 = open('/content/write.txt')

# counter = 0
# for line in fh1:
#   print(line[])      #What is this going to do? How do we fix this?
#   counter+=1



# for i in range(counter):
#   print(fh1.readline())
#   print(fh2.readline())
#   print("")
# Out:
# I threw a wish in the well
#
# I threw a wish in the well
#
#
# Don't ask me I'll never tell
#
# Don't ask me I'll never tell
#
#
# I looked at you as it fell
#
# I looked at you as it fell
#
#
# And now you're in my way
#
# And now you're in my way
#
#
# I'd trade my soul for a wish
#
# I'd trade my soul for a wish
#
#
# Pennies and dimes for a kiss
#
# Pennies and dimes for a kiss
#
#
# I wasn't looking for this
#
# I wasn't looking for this
#
#
# But now you're in my way
#
# But now you're in my way
#
#
# Your stare was holding
#
# Your stare was holding
#
#
# Ripped jeans, skin was showin'
#
# Ripped jeans, skin was showin'
#
#
# Hot night, wind was blowin'
#
# Hot night, wind was blowin'
#
#
# Where you think you're going baby?
#
# Where you think you're going baby?
#
#
# Hey, I just met you and this is crazy
#
# Hey, I just met you and this is crazy
#
#
# But here's my number, so call me maybe
#
# But here's my number, so call me maybe

# %%
#lab sorting

def insertionSort(arr): 
  
    # Traverse through 1 to len(arr) 
    for i in range(1, len(arr)): 
  
        key = arr[i] 
  
        # Move elements of arr[0..i-1], that are 
        # greater than key, to one position ahead 
        # of their current position 
        j = i-1
        while j >=0 and key < arr[j] : 
                #fill this in

        arr[j+1] = key 
  
  
# Driver code to test above 
arr = [12, 11, 13, 5, 6] 
insertionSort(arr) 
print ("Sorted array is:") 
for i in range(len(arr)): 
    print ("%d" %arr[i]) 
  



import sys 
A = [64, 25, 12, 22, 11] 
  
# Traverse through all array elements 
for i in range(len(A)): 
      
    # Find the minimum element in remaining  
    # unsorted array 
    min_idx = i 
    for j in range(i+1, len(A)): 
        if A[min_idx] > A[j]: 
            min_idx = j 
              
    # Swap the found minimum element with  
    # the first element         
    A[i], A[min_idx] = A[min_idx], A[i] 
  
# Driver code to test above 
print ("Sorted array") 
for i in range(len(A)): 
    print("%d" %A[i]),  



# Python program for implementation of MergeSort 
def mergeSort(arr): 
    if len(arr) >1: 
        mid = len(arr)//2 #Finding the mid of the array 
        L = arr[:mid] # Dividing the array elements  
        R = arr[mid:] # into 2 halves 
  
        mergeSort(L) # Sorting the first half 
        mergeSort(R) # Sorting the second half 
  
        i = j = k = 0
          
        # Copy data to temp arrays L[] and R[] 
        while i < len(L) and j < len(R): 
            if L[i] < R[j]: 
                arr[k] = L[i] 
                i+=1
            else: 
                arr[k] = R[j] 
                j+=1
            k+=1
          
        # Checking if any element was left 
        while i < len(L): 
            arr[k] = L[i] 
            i+=1
            k+=1
          
        while j < len(R): 
            arr[k] = R[j] 
            j+=1
            k+=1
  
# Code to print the list 
def printList(arr): 
    for i in range(len(arr)):         
        print(arr[i],end=" ") 
    print() 
  
# driver code to test the above code 
if __name__ == '__main__': 
    arr = [12, 11, 13, 5, 6, 7]  
    print ("Given array is", end="\n")  
    printList(arr) 
    mergeSort(arr) 
    print("Sorted array is: ", end="\n") 
    printList(arr)
